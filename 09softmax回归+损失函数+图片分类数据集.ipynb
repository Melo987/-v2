# %% [markdown]
# <a href="https://colab.research.google.com/github/Melo987/-v2/blob/main/09softmax%E5%9B%9E%E5%BD%92%2B%E6%8D%9F%E5%A4%B1%E5%87%BD%E6%95%B0%2B%E5%9B%BE%E7%89%87%E5%88%86%E7%B1%BB%E6%95%B0%E6%8D%AE%E9%9B%86.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Softmax回归**

# %% [markdown]
# **回归VS分类**
# 回归估计一个连续值，分类预测一个离散类别

# %% [markdown]
# ![1648606746(1).png](data:image/png;base64,...)

# %%
# 输出的个数是类别的个数

# %% [markdown]
# ![1648608236(1).png](data:image/png;base64,...)

# %%
# 对分类问题来讲，不关心实际的值，关心的是对正确类别的置信度是不是特别大
# 使对正确类的输出oy要远远大于其他类的oi

# %% [markdown]
# ![1648608506(1).png](data:image/png;base64,...)

# %% [markdown]
# ![1648608635(1).png](data:image/png;base64,...)

# %% [markdown]
# ![1648608979(1).png](data:image/png;base64,...)

# %% [markdown]
# ![1648609106(1).png](data:image/png;base64,...)

# %%
# 假设有n个类别，希望有n个输出，用softmax将输出结果概率化，用交叉熵做损失函数

# %% [markdown]
# # 损失函数

# %%
# 损失函数用来衡量预测值和真实值之间的区别

# %% [markdown]
#  L2 Loss(均方损失)，l(y, y′) =
# 1
# 2
# (y − y′)
# 2

# %%
# 按照负梯度方向更新参数时，当预测值距离真实值较远，更新范围非常大，不一定符合预期

# %% [markdown]
# L1 Loss（绝对值损失），l(y, y′) = | y − y′|

# %%
# 当预测值和真实值比较靠近时，即优化到末期，会变得不稳定

# %% [markdown]
# Huber's Robust Loss(鲁棒损失)，
#
# ![1648609809(1).png](data:image/png;base64,...)

# %%
# 相当于将均方损失与绝对值损失相结合

# %% [markdown]
# # 图像分类数据集

# %% [markdown]
# MNIST数据集时图像分类中广泛使用的数据集之一，但作为基准数据集过于简单。将使用类似但更复杂的Fashion-MNIST数据集

# %%
# %matplotlib inline
# !pip install -U d2l

# %%
import torch
import torchvision  
# torchvision是pytorch对计算机视觉一些模型实现的库
from torch.utils import data
# 方便读取数据小批量的函数
from torchvision import transforms
from d2l import torch as d2l

d2l.use_svg_display()

# %% [markdown]
# **通过框架中的内置函数将Fashion-MNIST数据集下载并读取到内存中**

# %%
# 通过ToTensor实例将图像数据从PIL类型变换成32位浮点数格式
# 并处以255使得所有像素的数值均在0到1之间
trans = transforms.ToTensor()
mnist_train = torchvision.datasets.FashionMNIST(
    root="../data",train=True,transform=trans,download=True)
mnist_test
